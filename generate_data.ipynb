# %%
# %load_ext autoreload
# %autoreload 2

from __future__ import division

import collections as cl

import numpy as np
import pylab as pl
import pandas as pd

# %matplotlib inline
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
def _sample_c(nfeatures, ngroups, zeta):
    """Generate indicator variables for differentially expressed transcripts"""

    ## allocate space
    c = np.zeros((nfeatures, ngroups), dtype='int')
    
    ## The first column of c is all zeros. Sample the second column of c
    w = np.r_[1, zeta]
    c[:, i] = np.choice(w.size, (nfeatures, 1), p=w / np.sum(w))
    
    ## continue if more than 2 groups are requested
    if ngroups > 2:
        for i in range(2, ngroups):
            ## find occupancies
            occ = [c[:, :i] == j for j in range(i+1)]
            occ = np.sum(occ, 2, dtype='float').T
            occ[range(nfeatures), np.max(c)+1] = zeta
            w = occ / np.sum(occ, 1).reshape(-1, 1)
            c[:, i] = [np.choice(wi.size, p=wi) for wi in w]

    ##
    return c

##

def _sample_delta(c, fraction_up, fraction_down, dsize):
    """Generate fold changes for each transcript"""
    
    nfeatures, ngroups = c.shape
    
    ## allocate space 
    delta = np.empty((nfeatures, ngroups))
    
    ## delta's for non-differentially expressed transcripts
    delta[c == 0] = 1
    
    ## delta's for differentially expressed transcripts
    for i in range(1, np.max(c) + 1):
        ## sample indicators for up- and down-regulation 
        x = np.choice([1,-1], (nfeatures, 1), p=[fraction_up,fraction_down])

        ## find positions of up- and down-regulated transcripts 
        up = np.logical_and(c == i, x == 1) 
        down = np.logical_and(c == i, x == -1)           

        ## sample delta's for up- and down-regulated transcripts
        rup = dsize + rn.exponential(size=(nfeatures, 1))
        rdown = 1 / (dsize + rn.exponential(size=(nfeatures, 1)))

        delta[up] = np.tile(rup, (1, ngroups))[up]
        delta[down] = np.tile(rdown, (1, ngroups))[down]

    ##
    return delta

## 

def generate_data_matrix(nfeatures=1000, ngroups=2, nreplicas=3, zeta=1, fraction_up=0.5, fraction_down=0.5, lib_depth=1e7, min_fact=0.7, max_fact=1.4, dsize=1):
    """Generate a matrix of count data"""
    
    ## a dictionary of the function arguments
    args = locals()
    
    ## sample indicator variables for differential expression
    c = _sample_c(nfeatures, ngroups, zeta)

    ## sample fold changes
    delta = _sample_delta(delta, fraction_up, fraction_down, dsize)
    
    ## sample library sizes
    nsamples = nreplicas * ngroups if np.size(nreplicas) == 1 else np.sum(nreplicas)
    facs = min_fact + (max_fact - min_fact) * rn.rand(nsamples)
    lib_sizes = lib_depth * facs    
    
    ## sample names and groups
    sample_names = ["sample%d" % x for x in range(1,nsamples+1)]
    group_names = ["group%d" % x for x in range(1,ngroups+1)]
    groups = np.repeat(group_names, nreplicas)
    
    ## sample mu and phi
    idxs = np.choice(len(PARS), (nfeatures, 1)) 
    phi, mu = PARS[idxs, [0]], PARS[idxs, [1]]    
    mu_fin = mu * delta * lib_sizes
    
    ## sample counts
    rates = rn.gamma()
    counts = rn.poisson(rates)
    
    ## construct dictionary for simulated data
    sim = cl.OrderedDict((
        ('counts', pd.DataFrame(counts, columns=sample_names)),
        ('lib_sizes', pd.DataFrame(lib_sizes, columns=sample_names)),
        ('groups', groups),
        ('mu', mu),
        ('phi', phi),
        ('delta', delta),
        ('c', c),
        ('args', args)
    ))
    
    ## 
    return sim
# Out:
#   File "<ipython-input-2-cc529a7140a6>", line 17
#
#     ^
# IndentationError: expected an indented block

# %%
np.sum([np.random.randint(3, size=(10,3)) for i in [1,2,3]], 2, dtype='float').T
# Out:
# array([[ 3.,  5.,  1.],
#        [ 2.,  2.,  2.],
#        [ 5.,  3.,  0.],
#        [ 2.,  4.,  2.],
#        [ 6.,  6.,  4.],
#        [ 3.,  3.,  4.],
#        [ 3.,  5.,  3.],
#        [ 4.,  6.,  0.],
#        [ 4.,  5.,  0.],
#        [ 2.,  2.,  4.]])

# %%
Out[41][0,0] = 1.1

# %%
Out[41]
# Out:
# array([[ 1.1,  5. ,  1. ],
#        [ 2. ,  2. ,  2. ],
#        [ 5. ,  3. ,  0. ],
#        [ 2. ,  4. ,  2. ],
#        [ 6. ,  6. ,  4. ],
#        [ 3. ,  3. ,  4. ],
#        [ 3. ,  5. ,  3. ],
#        [ 4. ,  6. ,  0. ],
#        [ 4. ,  5. ,  0. ],
#        [ 2. ,  2. ,  4. ]])

# %%
w = np.random.rand(20000,6); w = w / np.sum(w, 1).reshape(-1,1); map(lambda x: np.random.choice(x.size, p=x), w)
# Out:
# [3,
#  2,
#  3,
#  3,
#  2,
#  4,
#  5,
#  3,
#  0,
#  4,
#  3,
#  1,
#  2,
#  1,
#  5,
#  0,
#  0,
#  1,
#  1,
#  0,
#  1,
#  5,
#  3,
#  5,
#  1,
#  5,
#  2,
#  2,
#  4,
#  1,
#  2,
#  3,
#  3,
#  0,
#  3,
#  4,
#  2,
#  5,
#  2,
#  1,
#  5,
#  4,
#  2,
#  1,
#  5,
#  2,
#  1,
#  0,
#  5,
#  2,
#  0,
#  5,
#  2,
#  2,
#  4,
#  3,
#  5,
#  3,
#  3,
#  1,
#  1,
#  1,
#  1,
#  0,
#  3,
#  2,
#  5,
#  5,
#  0,
#  5,
#  0,
#  2,
#  1,
#  2,
#  1,
#  1,
#  4,
#  3,
#  4,
#  5,
#  3,
#  1,
#  4,
#  2,
#  0,
#  0,
#  5,
#  2,
#  4,
#  1,
#  1,
#  2,
#  3,
#  4,
#  2,
#  2,
#  1,
#  1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  2,
#  2,
#  3,
#  4,
#  5,
#  2,
#  4,
#  3,
#  2,
#  3,
#  5,
#  3,
#  1,
#  3,
#  5,
#  0,
#  1,
#  1,
#  3,
#  1,
#  1,
#  0,
#  3,
#  4,
#  4,
#  0,
#  2,
#  0,
#  1,
#  2,
#  3,
#  4,
#  2,
#  4,
#  5,
#  4,
#  3,
#  2,
#  5,
#  4,
#  1,
#  5,
#  0,
#  4,
#  3,
#  3,
#  4,
#  4,
#  5,
#  0,
#  2,
#  2,
#  3,
#  1,
#  3,
#  2,
#  4,
#  2,
#  3,
#  4,
#  4,
#  5,
#  3,
#  4,
#  4,
#  4,
#  0,
#  5,
#  2,
#  4,
#  1,
#  2,
#  2,
#  1,
#  5,
#  4,
#  1,
#  3,
#  3,
#  2,
#  1,
#  3,
#  2,
#  1,
#  4,
#  4,
#  5,
#  5,
#  5,
#  5,
#  3,
#  0,
#  0,
#  3,
#  2,
#  1,
#  3,
#  4,
#  2,
#  1,
#  2,
#  4,
#  1,
#  3,
#  4,
#  5,
#  2,
#  3,
#  0,
#  1,
#  1,
#  1,
#  3,
#  2,
#  3,
#  4,
#  2,
#  0,
#  1,
#  3,
#  5,
#  2,
#  4,
#  3,
#  1,
#  5,
#  3,
#  5,
#  0,
#  5,
#  4,
#  0,
#  1,
#  0,
#  1,
#  5,
#  5,
#  3,
#  3,
#  0,
#  5,
#  2,
#  0,
#  5,
#  2,
#  4,
#  3,
#  5,
#  2,
#  4,
#  2,
#  3,
#  2,
#  0,
#  5,
#  0,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  3,
#  0,
#  2,
#  1,
#  2,
#  0,
#  3,
#  0,
#  4,
#  2,
#  4,
#  5,
#  3,
#  0,
#  5,
#  1,
#  2,
#  5,
#  3,
#  3,
#  2,
#  2,
#  2,
#  5,
#  4,
#  3,
#  3,
#  5,
#  5,
#  5,
#  1,
#  5,
#  4,
#  2,
#  1,
#  5,
#  5,
#  2,
#  3,
#  0,
#  2,
#  1,
#  4,
#  2,
#  0,
#  3,
#  1,
#  0,
#  2,
#  3,
#  2,
#  2,
#  5,
#  4,
#  4,
#  3,
#  5,
#  3,
#  2,
#  3,
#  4,
#  4,
#  5,
#  0,
#  1,
#  5,
#  3,
#  0,
#  0,
#  2,
#  1,
#  0,
#  5,
#  2,
#  2,
#  3,
#  0,
#  4,
#  5,
#  0,
#  4,
#  2,
#  4,
#  3,
#  2,
#  4,
#  1,
#  4,
#  4,
#  4,
#  2,
#  0,
#  2,
#  5,
#  4,
#  4,
#  1,
#  5,
#  4,
#  2,
#  5,
#  3,
#  2,
#  0,
#  1,
#  1,
#  4,
#  1,
#  4,
#  3,
#  0,
#  2,
#  4,
#  2,
#  4,
#  4,
#  5,
#  3,
#  0,
#  4,
#  5,
#  1,
#  1,
#  0,
#  2,
#  1,
#  1,
#  3,
#  4,
#  1,
#  0,
#  1,
#  1,
#  1,
#  1,
#  0,
#  2,
#  1,
#  0,
#  5,
#  4,
#  5,
#  2,
#  3,
#  0,
#  1,
#  5,
#  0,
#  1,
#  5,
#  4,
#  0,
#  3,
#  5,
#  2,
#  5,
#  4,
#  3,
#  4,
#  0,
#  1,
#  0,
#  5,
#  3,
#  0,
#  3,
#  4,
#  4,
#  3,
#  0,
#  3,
#  1,
#  4,
#  5,
#  3,
#  3,
#  5,
#  3,
#  0,
#  4,
#  0,
#  2,
#  0,
#  1,
#  5,
#  5,
#  0,
#  3,
#  2,
#  2,
#  2,
#  1,
#  4,
#  0,
#  3,
#  0,
#  5,
#  4,
#  3,
#  2,
#  2,
#  4,
#  2,
#  1,
#  4,
#  3,
#  3,
#  3,
#  0,
#  1,
#  0,
#  5,
#  2,
#  5,
#  2,
#  1,
#  2,
#  3,
#  2,
#  4,
#  4,
#  3,
#  0,
#  4,
#  0,
#  0,
#  0,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  5,
#  4,
#  0,
#  3,
#  2,
#  0,
#  4,
#  0,
#  4,
#  5,
#  3,
#  2,
#  1,
#  3,
#  0,
#  4,
#  1,
#  1,
#  2,
#  5,
#  4,
#  0,
#  0,
#  2,
#  1,
#  3,
#  3,
#  3,
#  5,
#  2,
#  0,
#  4,
#  3,
#  5,
#  2,
#  4,
#  4,
#  1,
#  4,
#  5,
#  1,
#  5,
#  1,
#  1,
#  2,
#  3,
#  3,
#  2,
#  5,
#  2,
#  2,
#  2,
#  4,
#  3,
#  1,
#  5,
#  2,
#  3,
#  1,
#  4,
#  3,
#  5,
#  0,
#  3,
#  1,
#  5,
#  4,
#  0,
#  1,
#  4,
#  4,
#  0,
#  1,
#  4,
#  2,
#  0,
#  5,
#  2,
#  1,
#  5,
#  5,
#  1,
#  1,
#  1,
#  1,
#  5,
#  4,
#  0,
#  2,
#  0,
#  0,
#  0,
#  4,
#  1,
#  2,
#  2,
#  2,
#  4,
#  4,
#  4,
#  4,
#  2,
#  2,
#  2,
#  1,
#  0,
#  4,
#  4,
#  2,
#  4,
#  0,
#  2,
#  0,
#  2,
#  5,
#  5,
#  0,
#  1,
#  1,
#  5,
#  0,
#  5,
#  4,
#  1,
#  1,
#  0,
#  5,
#  4,
#  2,
#  4,
#  4,
#  3,
#  2,
#  1,
#  3,
#  5,
#  3,
#  0,
#  3,
#  4,
#  3,
#  2,
#  4,
#  0,
#  5,
#  2,
#  0,
#  5,
#  4,
#  4,
#  3,
#  2,
#  5,
#  0,
#  0,
#  1,
#  1,
#  0,
#  1,
#  5,
#  0,
#  5,
#  4,
#  3,
#  2,
#  3,
#  2,
#  1,
#  2,
#  4,
#  5,
#  4,
#  0,
#  1,
#  0,
#  0,
#  2,
#  2,
#  2,
#  0,
#  3,
#  0,
#  2,
#  5,
#  0,
#  3,
#  5,
#  4,
#  5,
#  1,
#  5,
#  2,
#  4,
#  0,
#  1,
#  4,
#  2,
#  1,
#  0,
#  4,
#  1,
#  5,
#  0,
#  0,
#  5,
#  5,
#  2,
#  4,
#  5,
#  3,
#  0,
#  4,
#  0,
#  2,
#  2,
#  0,
#  4,
#  5,
#  4,
#  4,
#  2,
#  2,
#  5,
#  0,
#  0,
#  1,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  5,
#  5,
#  3,
#  4,
#  0,
#  4,
#  0,
#  2,
#  4,
#  0,
#  4,
#  0,
#  2,
#  0,
#  3,
#  4,
#  2,
#  1,
#  5,
#  2,
#  1,
#  1,
#  2,
#  3,
#  5,
#  5,
#  1,
#  1,
#  3,
#  3,
#  2,
#  0,
#  4,
#  0,
#  3,
#  3,
#  1,
#  4,
#  5,
#  2,
#  0,
#  1,
#  5,
#  1,
#  0,
#  0,
#  5,
#  5,
#  0,
#  0,
#  5,
#  3,
#  4,
#  1,
#  0,
#  5,
#  3,
#  3,
#  4,
#  4,
#  5,
#  0,
#  4,
#  0,
#  5,
#  0,
#  2,
#  5,
#  2,
#  4,
#  3,
#  0,
#  3,
#  1,
#  1,
#  5,
#  4,
#  5,
#  4,
#  0,
#  1,
#  5,
#  1,
#  5,
#  5,
#  5,
#  1,
#  2,
#  0,
#  1,
#  4,
#  0,
#  3,
#  0,
#  1,
#  4,
#  5,
#  1,
#  1,
#  2,
#  2,
#  0,
#  5,
#  2,
#  1,
#  3,
#  0,
#  2,
#  4,
#  5,
#  2,
#  2,
#  1,
#  4,
#  2,
#  4,
#  3,
#  2,
#  3,
#  2,
#  1,
#  4,
#  3,
#  4,
#  3,
#  5,
#  5,
#  1,
#  0,
#  0,
#  1,
#  5,
#  4,
#  1,
#  3,
#  0,
#  3,
#  4,
#  2,
#  5,
#  0,
#  3,
#  0,
#  4,
#  4,
#  3,
#  3,
#  0,
#  4,
#  2,
#  4,
#  1,
#  5,
#  0,
#  2,
#  0,
#  1,
#  3,
#  1,
#  1,
#  2,
#  1,
#  0,
#  4,
#  4,
#  5,
#  4,
#  4,
#  3,
#  3,
#  0,
#  1,
#  5,
#  4,
#  3,
#  2,
#  5,
#  3,
#  4,
#  4,
#  3,
#  0,
#  3,
#  2,
#  1,
#  2,
#  1,
#  2,
#  2,
#  0,
#  4,
#  5,
#  3,
#  1,
#  1,
#  4,
#  1,
#  3,
#  1,
#  0,
#  3,
#  0,
#  4,
#  0,
#  3,
#  4,
#  5,
#  2,
#  1,
#  5,
#  1,
#  5,
#  2,
#  1,
#  1,
#  3,
#  5,
#  5,
#  2,
#  2,
#  1,
#  3,
#  1,
#  4,
#  4,
#  4,
#  1,
#  5,
#  1,
#  0,
#  3,
#  5,
#  5,
#  1,
#  4,
#  5,
#  1,
#  4,
#  1,
#  2,
#  1,
#  1,
#  1,
#  3,
#  4,
#  2,
#  5,
#  4,
#  1,
#  0,
#  5,
#  4,
#  5,
#  4,
#  4,
#  2,
#  0,
#  1,
#  0,
#  3,
#  5,
#  5,
#  1,
#  5,
#  4,
#  4,
#  ...]
